# %% [markdown]
# The first attempt at answering the question: "should Leonardo DiCaprio have won an oscar for an earlier performance?" resulted in models that grossly over predicted the number of nominations and wins for best actor. Additionally, both of the original models seemed to agree on which titles should have receieved nominations, but differed slightly as to whether the particular title should have won. One performance they both agreed upon was his portrayal of Arnie Grape in What's Eating Gilbert Grape. From this original data set it was apparent that additional information was necessary, for example: How important is the role to the title? How old was the actor when they appeared in the title? We attempt to improve the reliability of the DiCaprio predictions by adding more features to the data set.
#
# The new datasets were retrieved from: https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset

# %%
import pandas as pd
import numpy as np
import datetime as dt
import re
import unidecode
import glob

# %%
movies_df = pd.read_csv('IMDb_movies.csv', usecols=['imdb_title_id','year','date_published','duration','budget','worlwide_gross_income','metascore','avg_vote','votes'],low_memory=False)
names_df = pd.read_csv('IMDb_names.csv', usecols=['imdb_name_id','name','height','date_of_birth'])
principals_df = pd.read_csv('IMDb_title_principals.csv', usecols=['imdb_title_id','imdb_name_id','ordering'], low_memory=False)
titles_df = pd.read_csv('title.basics.tsv',sep='\t', usecols=['tconst','primaryTitle'])
ratings_df = pd.read_csv('IMDb_ratings.csv')
ba_df = pd.read_csv('processed_data.csv')

# %% [markdown]
# While exploring the titles column in the movies_df, a large portion of the title information was stored in french and spanish. This neccessitated the extraction of title information from the larger comprehensive data set from IMDb.

# %%
titles_df.rename({'tconst':'imdb_title_id','primaryTitle':'title'}, axis ='columns', inplace=True)
names_df.rename({'name':'actor'}, axis ='columns',inplace=True)
ba_df.rename(str.lower, axis ='columns',inplace=True)
names_df.actor = names_df.actor.apply(lambda x: unidecode.unidecode(str(x)))

# %% [markdown]
# Here columns are given consistent names across data sets for easier joining. Additionally actor names are converted to unicode characters to match those in the original data set, ensuring that all actors that have received an academy award or nomination remain after filtering.

# %%
actor_list = ba_df['actor'].unique().tolist()
names_df = names_df[names_df.actor.isin(actor_list)]

# %% [markdown]
# The data set retrieved from kaggle is filtered such that only the actors that have been nominated for or won the academy award for best actor remain.

# %%
names_df.at[38127,'height']=175.0
names_df.at[38127,'date_of_birth']='1916-12-09'
names_df.at[71464,'height']=183.0
names_df.at[81083,'height']=188.0
names_df.at[85305,'height']=191.0
names_df.at[85305,'date_of_birth']='1896-08-30'
names_df.at[119054,'height']=188.0
names_df.at[127665,'height']=179.0
names_df.at[161858,'height']=178.0
names_df.at[161858,'date_of_birth']='1907-05-22'
names_df.at[177644,'height']=182.0
names_df.at[183892,'height']=1.0
names_df.at[183892,'date_of_birth']='1900-01-01'
names_df.at[218016,'height']=1.0
names_df.at[218016,'date_of_birth']='1900-01-01'
names_df.at[282012,'height']=1.0

# %% [markdown]
# Due to discrepancies in the new dataset found on kaggle, there are missing values in the height and dob columns for several actors, and are manually adjusted when data could be found. In two cases no further record of actor height or dob could be found, so basic values and dates were assigned.

# %%
movies_named = pd.merge(titles_df,movies_df, how='inner',on='imdb_title_id')
principals_named = pd.merge(principals_df, names_df, how='inner',on=['imdb_name_id'])
movies_rated = pd.merge(movies_named, ratings_df, how='inner', on='imdb_title_id')
big_df = pd.merge(principals_named,movies_rated, how='inner', on='imdb_title_id')

# %% [markdown]
# The different data sets are joined on the imdb title and name id's associated with each actor and the titles they are associated with. These are in turn dropped as they are irrelevant to the analyses.

# %%
big_df = big_df.fillna('0')
big_df.drop(['imdb_title_id','imdb_name_id'], axis=1, inplace=True)

# %%
big_df.at[9181,'title'] = 'Star Wars the Rise of Skywalker'
big_df.at[3221,'date_published'] = '2019-09-08'
big_df.at[3221,'year']='2019'

# %% [markdown]
# IMDb id columns are dropped, and at this point it was noticed that an aberrant value was located in the year and date_published columns for row 3221 as well as a title discrepancy in row 9181. Fixing the date values solved the issue with converting to datetime objects. The discrepancy *noticed* with the title name suggests that there are other possible discrepancies.

# %%
big_df.year = pd.to_datetime(big_df.year, format='%Y').dt.year

for datecol in ['date_of_birth','date_published']:
    big_df['{}'.format(datecol)] = pd.to_datetime(big_df['{}'.format(datecol)], format='%Y-%m-%d').dt.date

# %%
big_df['age_at_performance'] = (big_df.year - pd.DatetimeIndex(big_df['date_of_birth']).year).astype('timedelta64[Y]')/ np.timedelta64(1, 'Y')

# %% [markdown]
# All date columns are converted from string to datetime objects, and since the formatting of both columns is consistent they can be looped over with the same conversion.
#
# The actor age at performance is created as a time delta between the actor date of birth and the date of publishing for the title they appeared in.

# %%
big_df.title = big_df.title.apply(lambda x: re.sub('\.\.\.|\:|\;|\,|\.|\'', '', unidecode.unidecode(str(x).strip())).lower())
big_df.actor = big_df.actor.apply(lambda x: unidecode.unidecode(str(x)))
for moneycol in ['budget','worlwide_gross_income']:
    big_df['{}'.format(moneycol)] = big_df['{}'.format(moneycol)].str.extract('(\d+)', expand=False).astype(int)

# %% [markdown]
# The same subsitution and dropping of particular characters and conversion to unicode that was done to the first data set is done here as well to ensure continuity, as these will be the columns used to merge onto the original dataset.

# %%
big_df.drop(['date_of_birth','date_published'],axis=1, inplace=True)
big_df.head(5)
# Out:
#    ordering          actor  height                  title  year  duration  \
# 0         2  Emil Jannings   183.0                passion  1919        85
# 1         3  Emil Jannings   183.0  the eyes of the mummy  1918        63
# 2         2  Emil Jannings   183.0         the merry jail  1917        48
# 3         1  Emil Jannings   183.0                  power  1920        99
# 4         2  Emil Jannings   183.0              deception  1920       100
#
#    avg_vote  votes  budget  worlwide_gross_income  ... females_30age_votes  \
# 0       6.8    753       0                      0  ...                  40
# 1       5.5    554       0                      0  ...                  12
# 2       6.2    515       0                      0  ...                  27
# 3       6.3    138       0                      0  ...                   7
# 4       6.6    576       0                      0  ...                  19
#
#    females_45age_avg_vote  females_45age_votes  top1000_voters_rating  \
# 0                     8.2                   34                    6.2
# 1                     6.1                   19                    5.6
# 2                     7.2                   42                    5.3
# 3                     6.5                    2                    6.1
# 4                     7.1                   28                    6.3
#
#    top1000_voters_votes  us_voters_rating  us_voters_votes  \
# 0                    88               6.6            139.0
# 1                    81               5.3            178.0
# 2                    38               6.3            224.0
# 3                    26               5.5             21.0
# 4                    88               6.5            144.0
#
#    non_us_voters_rating  non_us_voters_votes  age_at_performance
# 0                   6.8                455.0                35.0
# 1                   5.6                219.0                34.0
# 2                   6.1                198.0                33.0
# 3                   6.4                 80.0                36.0
# 4                   6.6                318.0                36.0
#
# [5 rows x 60 columns]

# %%
big_df.describe()
# Out:
#           ordering       height         year     duration     avg_vote  \
# count  9404.000000  9404.000000  9404.000000  9404.000000  9404.000000
# mean      1.942897   180.293067  1977.481923   105.737346     6.478031
# std       1.295216     7.624958    27.369836    22.138056     0.895620
# min       1.000000     1.000000  1917.000000    45.000000     1.800000
# 25%       1.000000   175.000000  1954.000000    92.000000     6.000000
# 50%       1.000000   180.000000  1980.000000   103.000000     6.500000
# 75%       3.000000   185.000000  2002.000000   117.000000     7.100000
# max      10.000000   196.000000  2020.000000   357.000000     9.300000
#
#               votes        budget  worlwide_gross_income  \
# count  9.404000e+03  9.404000e+03           9.404000e+03
# mean   5.456646e+04  1.681209e+07           4.026085e+07
# std    1.573348e+05  9.802206e+07           1.283905e+08
# min    1.000000e+02  0.000000e+00           0.000000e+00
# 25%    6.610000e+02  0.000000e+00           0.000000e+00
# 50%    3.443500e+03  4.000000e+05           0.000000e+00
# 75%    2.952050e+04  1.500000e+07           1.566642e+07
# max    2.278845e+06  7.000000e+09           2.797801e+09
#
#        weighted_average_vote   total_votes  ...  males_30age_votes  \
# count            9404.000000  9.404000e+03  ...        9404.000000
# mean                6.478031  5.456646e+04  ...       19273.918545
# std                 0.895620  1.573348e+05  ...       53238.889701
# min                 1.800000  1.000000e+02  ...           5.000000
# 25%                 6.000000  6.610000e+02  ...         121.000000
# 50%                 6.500000  3.443500e+03  ...         889.000000
# 75%                 7.100000  2.952050e+04  ...       10409.000000
# max                 9.300000  2.278845e+06  ...      743676.000000
#
#        males_45age_avg_vote  males_45age_votes  females_allages_avg_vote  \
# count           9404.000000        9404.000000               9404.000000
# mean               6.423203        5799.456933                  6.605838
# std                0.897744       12436.542185                  0.897784
# min                1.600000           9.000000                  1.200000
# 25%                5.900000         264.000000                  6.100000
# 50%                6.500000        1095.000000                  6.700000
# 75%                7.000000        5469.000000                  7.200000
# max                9.200000      165852.000000                 10.000000
#
#        females_allages_votes  us_voters_rating  us_voters_votes  \
# count            9404.000000       9404.000000      9404.000000
# mean             7188.005849          6.527935      9252.549128
# std             20601.778072          0.924482     23857.669423
# min                 1.000000          1.500000         4.000000
# 25%                82.000000          6.000000       231.000000
# 50%               418.000000          6.600000      1004.000000
# 75%              3856.000000          7.100000      6624.000000
# max            278964.000000          9.300000    348363.000000
#
#        non_us_voters_rating  non_us_voters_votes  age_at_performance
# count           9404.000000          9404.000000         9404.000000
# mean               6.364419         24526.527648           46.666950
# std                0.918541         66670.230287           13.641218
# min                1.000000             6.000000            9.000000
# 25%                5.900000           235.000000           36.000000
# 50%                6.400000          1422.500000           45.000000
# 75%                6.900000         13752.000000           56.000000
# max                9.500000        887226.000000          121.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# At this point it is worth mentioning that big_df reflects only the information for the actors with names matching those from the initial data set that are of interest, and that there are considerably fewer entries.

# %%
big_df[(big_df.age_at_performance>90)]
# Out:
#       ordering             actor  height  \
# 2736         5      Orson Welles   183.0
# 2750         7      Orson Welles   183.0
# 2751         1      Orson Welles   183.0
# 4373         1   Ernest Borgnine   177.0
# 4374         1   Ernest Borgnine   177.0
# 4375         4   Ernest Borgnine   177.0
# 4376         1   Ernest Borgnine   177.0
# 4377         1   Ernest Borgnine   177.0
# 8953         8    Raymond Massey   191.0
# 8954         7    Raymond Massey   191.0
# 8955         9    Raymond Massey   191.0
# 8956         7    Raymond Massey   191.0
# 9278         9      Kirk Douglas   175.0
# 9279         8      Kirk Douglas   175.0
# 9377         9        James Dean     1.0
# 9392         3        James Dean     1.0
# 9403         6  Laurence Olivier   178.0
#
#                                                 title  year  duration  \
# 2736                       the other side of the wind  2018       122
# 2750                                   the hitchhiker  2007        86
# 2751                                             jucy  2010        90
# 4373                             another harvest moon  2010        89
# 4374                                the lion of judah  2011        87
# 4375                                 the genesis code  2010       138
# 4376                                       night club  2011        95
# 4377  the man who shook the hand of vicente fernandez  2012        99
# 8953                                      whale music  1994       107
# 8954                                      black point  2002       100
# 8955                 long life happiness & prosperity  2002        90
# 8956                                  meditation park  2017        94
# 9278                                          sutures  2009        83
# 9279                                         whispers  2015        90
# 9377                                    the tattooist  2007        92
# 9392                                              icu  2009        85
# 9403                             ghost town anthology  2019        97
#
#       avg_vote  votes    budget  worlwide_gross_income  ...  \
# 2736       6.8   5887         0                      0  ...
# 2750       3.6    938    500000                      0  ...
# 2751       5.7    110    150000                      0  ...
# 4373       6.0    182         0                      0  ...
# 4374       3.4    527  15000000                      0  ...
# 4375       5.3    633   5100000                      0  ...
# 4376       6.5    229   1000000                      0  ...
# 4377       6.1    284         0                  10782  ...
# 8953       7.1    532         0                      0  ...
# 8954       5.2    552   6000000                      0  ...
# 8955       6.5    550         0                      0  ...
# 8956       7.1    452   2000000                  59530  ...
# 9278       4.1   1455         0                      0  ...
# 9279       4.3   8838         0                      0  ...
# 9377       5.1   3024   3000000                 645898  ...
# 9392       2.6    501   1100000                      0  ...
# 9403       6.4   1198         0                      0  ...
#
#      females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 2736                 117                     5.5                   62
# 2750                  62                     5.9                   38
# 2751                  26                     5.4                   12
# 4373                   9                     5.5                   22
# 4374                  37                       7                   18
# 4375                  57                     6.4                   68
# 4376                  17                     5.7                   23
# 4377                  15                     7.5                   19
# 8953                  17                     7.1                   24
# 8954                  26                     4.8                   27
# 8955                  76                       7                   71
# 8956                  50                       8                   57
# 9278                  86                     4.4                   37
# 9279                 250                     3.6                  105
# 9377                 389                     5.4                  108
# 9392                  49                     3.9                   23
# 9403                  74                     6.9                   21
#
#       top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 2736                    5.9                   190               6.9
# 2750                      4                    29               4.3
# 2751                      3                     4               5.3
# 4373                    4.8                    32               6.5
# 4374                    2.9                    22               3.6
# 4375                    4.7                    49               5.4
# 4376                      6                    24               6.8
# 4377                    4.9                    29               6.8
# 8953                    5.4                    20               6.9
# 8954                    4.8                    43               5.2
# 8955                    5.6                    51               6.7
# 8956                    5.9                    23               7.5
# 9278                    4.6                    60               4.2
# 9279                      5                    59               4.4
# 9377                    4.4                    90               5.2
# 9392                    3.2                    55               3.2
# 9403                    5.6                    49               6.2
#
#       us_voters_votes  non_us_voters_rating  non_us_voters_votes  \
# 2736           1349.0                   6.7               2504.0
# 2750            345.0                   3.1                445.0
# 2751             32.0                   5.8                 58.0
# 4373             81.0                   5.4                 60.0
# 4374            130.0                   3.3                243.0
# 4375            275.0                   4.0                109.0
# 4376            135.0                   5.9                 33.0
# 4377            108.0                   5.5                 99.0
# 8953             47.0                   6.8                276.0
# 8954            132.0                   5.3                277.0
# 8955            253.0                   6.1                151.0
# 8956             74.0                   7.1                200.0
# 9278            433.0                   4.1                302.0
# 9279            932.0                   3.6                566.0
# 9377            515.0                   5.0               1883.0
# 9392            111.0                   2.1                294.0
# 9403             71.0                   6.5                735.0
#
#       age_at_performance
# 2736               103.0
# 2750                92.0
# 2751                95.0
# 4373                93.0
# 4374                94.0
# 4375                93.0
# 4376                94.0
# 4377                95.0
# 8953                98.0
# 8954               106.0
# 8955               106.0
# 8956               121.0
# 9278                93.0
# 9279                99.0
# 9377               107.0
# 9392               109.0
# 9403               112.0
#
# [17 rows x 60 columns]

# %% [markdown]
# From the descriptive analysis above, it was noticed that the maximum age_at_performance was 121 y/o. This helps to see that this is caused by missing information for dob in an earlier attempt to provide information for Raymond Massey and James Dean(not the first) which could not be found by any means

# %%
shortened_df = pd.merge(ba_df, big_df, how='inner',on=['actor','title'])

# %%
exclude_roles = ['director','producer','executive producer','narrator','host','writer','original music', 'music','screenwriter','himself']
shortened_df = shortened_df[~shortened_df.role.isin(exclude_roles)]

# %%
shortened_df[shortened_df.age_at_performance>90]
# Out:
#                 actor         role  \
# 8003  Ernest Borgnine          rex
# 8004  Ernest Borgnine        slink
# 8005  Ernest Borgnine  carl taylor
# 8006  Ernest Borgnine        frank
#
#                                                 title  award  score_1  \
# 8003  the man who shook the hand of vicente fernandez    0.0     68.0
# 8004                                the lion of judah    0.0     62.0
# 8005                                 the genesis code    0.0      0.0
# 8006                             another harvest moon    0.0      0.0
#
#       score_2  num_reviews  polarity_mean  objectivity_mean  numeric_key  ...  \
# 8003     40.0          3.0      -0.131944          0.415278           62  ...
# 8004      0.0          2.0       0.050000          0.825000           62  ...
# 8005      0.0          0.0       0.000000          0.000000           62  ...
# 8006      0.0          1.0       0.256250          0.462500           62  ...
#
#       females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 8003                   15                     7.5                   19
# 8004                   37                       7                   18
# 8005                   57                     6.4                   68
# 8006                    9                     5.5                   22
#
#       top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 8003                    4.9                    29               6.8
# 8004                    2.9                    22               3.6
# 8005                    4.7                    49               5.4
# 8006                    4.8                    32               6.5
#
#       us_voters_votes  non_us_voters_rating non_us_voters_votes  \
# 8003            108.0                   5.5                99.0
# 8004            130.0                   3.3               243.0
# 8005            275.0                   4.0               109.0
# 8006             81.0                   5.4                60.0
#
#       age_at_performance
# 8003                95.0
# 8004                94.0
# 8005                93.0
# 8006                93.0
#
# [4 rows x 68 columns]

# %% [markdown]
# Confirming that the erroneous information was not retained during merge.

# %%
shortened_df
# Out:
#                 actor                role                        title  award  \
# 0         Adam Driver      charlie barber               marriage story    1.0
# 1      Adolphe Menjou        walter burns               the front page    1.0
# 2        Adrien Brody  wladyslaw szpilman                  the pianist    2.0
# 3           Al Pacino       frank serpico                      serpico    1.0
# 4           Al Pacino    michael corleone        the godfather part ii    1.0
# ...               ...                 ...                          ...    ...
# 8416  Terrence Howard  lt lincoln a scott                    harts war    0.0
# 8417  Terrence Howard               robby                   angel eyes    0.0
# 8418  Terrence Howard               chris  love beat the hell outta me    0.0
# 8419  Terrence Howard               byron                        spark    0.0
# 8420  Terrence Howard            spaceman                  sunset park    0.0
#
#       score_1  score_2  num_reviews  polarity_mean  objectivity_mean  \
# 0        85.0     94.0         48.0       0.190969          0.479507
# 1        60.0     93.0          1.0       0.500000          1.000000
# 2        96.0     95.0         40.0       0.128576          0.603966
# 3        88.0     90.0          6.0       0.238542          0.572917
# 4        97.0     98.0         17.0       0.380286          0.646926
# ...       ...      ...          ...            ...               ...
# 8416     48.0     59.0         36.0       0.128374          0.495090
# 8417     46.0     33.0         38.0       0.102158          0.544197
# 8418      0.0      0.0          0.0       0.000000          0.000000
# 8419      0.0      0.0          0.0       0.000000          0.000000
# 8420     83.0     13.0          3.0       0.336111          0.491667
#
#       numeric_key  ...  females_30age_votes  females_45age_avg_vote  \
# 0               0  ...                14992                     7.5
# 1               1  ...                   81                     6.8
# 2               2  ...                53249                     8.4
# 3               3  ...                 3241                     7.8
# 4               3  ...                47656                     8.7
# ...           ...  ...                  ...                     ...
# 8416          206  ...                 2185                     6.6
# 8417          206  ...                 3611                     6.1
# 8418          206  ...                   10                     2.8
# 8419          206  ...                   15                     6.4
# 8420          206  ...                  119                     6.3
#
#       females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 0                    3370                    7.1                   419
# 1                     134                    6.5                   184
# 2                   10601                    8.1                   739
# 3                    1742                    7.6                   624
# 4                   16306                    8.8                   856
# ...                   ...                    ...                   ...
# 8416                  995                    6.2                   428
# 8417                 1076                    5.3                   338
# 8418                   17                    3.5                    11
# 8419                   23                    5.2                    16
# 8420                   32                    5.5                    95
#
#       us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 0                  8.0          22814.0                   7.9
# 1                  6.8           1080.0                   6.6
# 2                  8.4          82064.0                   8.5
# 3                  7.7          19673.0                   7.7
# 4                  9.1         164758.0                   9.0
# ...                ...              ...                   ...
# 8416               6.3          10113.0                   6.3
# 8417               5.5           5027.0                   5.6
# 8418               3.9             61.0                   1.0
# 8419               5.5             93.0                   5.4
# 8420               6.1            632.0                   5.9
#
#      non_us_voters_votes  age_at_performance
# 0                88146.0                36.0
# 1                  663.0                41.0
# 2               323314.0                29.0
# 3                53318.0                33.0
# 4               448555.0                34.0
# ...                  ...                 ...
# 8416             25963.0                33.0
# 8417             10778.0                32.0
# 8418                11.0                31.0
# 8419                77.0                29.0
# 8420               446.0                27.0
#
# [8340 rows x 68 columns]

# %% [markdown]
# When joining the data sets on the actor and title columns, as well as dropping the non-performance based credits the resulting data set has 8,340 entries. The original data set contained 14,474 entries suggesting a difference of 43.4% of the data by adding more features to the data.

# %%
shortened_df.describe()
# Out:
#              award      score_1      score_2  num_reviews  polarity_mean  \
# count  8340.000000  8340.000000  8340.000000  8340.000000    8340.000000
# mean      0.063909    40.599640    40.608873     9.725659       0.085345
# std       0.285757    34.446202    37.447243    14.160255       0.159247
# min       0.000000     0.000000     0.000000     0.000000      -1.000000
# 25%       0.000000     0.000000     0.000000     0.000000       0.000000
# 50%       0.000000    46.000000    39.000000     2.000000       0.000000
# 75%       0.000000    73.000000    78.000000    14.000000       0.171954
# max       2.000000    99.000000   100.000000    66.000000       1.000000
#
#        objectivity_mean  numeric_key     ordering       height         year  \
# count       8340.000000  8340.000000  8340.000000  8340.000000  8340.000000
# mean           0.333301   116.752878     1.812110   180.458513  1977.037290
# std            0.287861    66.502140     1.037871     6.953434    27.368352
# min            0.000000     0.000000     1.000000   157.000000  1917.000000
# 25%            0.000000    63.000000     1.000000   175.000000  1953.000000
# 50%            0.466580   115.000000     1.000000   180.000000  1979.000000
# 75%            0.572105   173.000000     2.000000   186.000000  2002.000000
# max            1.000000   232.000000    10.000000   196.000000  2020.000000
#
#        ...  males_30age_votes  males_45age_avg_vote  males_45age_votes  \
# count  ...        8340.000000           8340.000000        8340.000000
# mean   ...       20230.250839              6.455408        6095.756595
# std    ...       53995.163243              0.878404       12494.841276
# min    ...           5.000000              1.600000          11.000000
# 25%    ...         136.000000              6.000000         301.750000
# 50%    ...        1065.000000              6.500000        1278.500000
# 75%    ...       12050.000000              7.000000        6017.250000
# max    ...      743676.000000              9.200000      165852.000000
#
#        females_allages_avg_vote  females_allages_votes  us_voters_rating  \
# count               8340.000000            8340.000000       8340.000000
# mean                   6.626918            7481.309832          6.553381
# std                    0.872528           20909.731628          0.907233
# min                    1.200000               1.000000          1.500000
# 25%                    6.200000              94.000000          6.100000
# 50%                    6.700000             495.500000          6.600000
# 75%                    7.200000            4308.250000          7.100000
# max                   10.000000          278964.000000          9.300000
#
#        us_voters_votes  non_us_voters_rating  non_us_voters_votes  \
# count      8340.000000           8340.000000          8340.000000
# mean       9724.732494              6.392758         25678.468225
# std       24100.386069              0.895061         67603.998745
# min           6.000000              1.000000             6.000000
# 25%         273.000000              5.900000           267.750000
# 50%        1187.500000              6.400000          1699.000000
# 75%        7364.000000              7.000000         15904.000000
# max      348363.000000              9.500000        887226.000000
#
#        age_at_performance
# count         8340.000000
# mean            46.415588
# std             13.341051
# min              9.000000
# 25%             36.000000
# 50%             45.000000
# 75%             56.000000
# max             95.000000
#
# [8 rows x 46 columns]

# %%
shortened_df.award.value_counts()
# Out:
# 0.0    7898
# 1.0     351
# 2.0      91
# Name: award, dtype: int64

# %% [markdown]
# Here it can be noted that several nominations and wins are not present in this dataset.

# %%
shortened_df.to_csv('best_actor_hd.csv', index=False)
